# %%
import pickle 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../../lib/')
from frustration_traditional import *

# %%
L = 26
res = np.loadtxt(f"../../Results/Ising_Frustrated/DWave/Magnetizations_walls_{L}x{L}.dat")

# %%
df = pd.DataFrame(res, columns=["Ratio", "M", "M_std", "W", "W_std"])

# %%
df.plot(x='Ratio', y=["M"])
# Out:
# <AxesSubplot: xlabel='Ratio'>

# %%
df.plot(x='Ratio', y=["B"])
# Out:
# <AxesSubplot: xlabel='Ratio'>

# %%
df.plot(x='Ratio', y=["W"])
# Out:
# <AxesSubplot: xlabel='Ratio'>
