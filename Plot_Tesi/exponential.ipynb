# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
t = [0.46, 4.52, 15.69, 405.91]
lattices = np.array([10, 20, 30, 40])

# %%
plt.plot(lattices, np.log10(t))
plt.plot(lattices, lattices/10-1.35)
plt.grid()
plt.xlabel("L")
plt.ylabel("log10(t)")
# Out:
# Text(0, 0.5, 'log10(t)')
